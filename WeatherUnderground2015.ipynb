# %%
import urllib2
import pandas as pd
from bs4 import BeautifulSoup

weather_data = []
date = []
#we set data sets and then we put a for loop to get the data sets under the given range
for y in range(2015,2016):
    for m in range(1, 13):
        for d in range(1, 32):
        #we check for the leap year conditionality to include in any abnormalities in the data set by function leapyear
            if y%400 == 0:
                leapyear = True
            elif y%100 == 0:
                leapyear = False
            elif y%4 == 0:
                leapyear = True
            else:
                leapyear = False

#to prevent double scraping, we check if dates have already been scraped  

            if (m==2 and leapyear and d>29):
                continue
            elif (y==2013 and m==2 and d > 28):
                continue
            elif(m in [4, 6, 9, 11] and d > 30):
                continue
#we put a timestamp on the data set
            timestamp = str(y) + str(m) + str(d)
            print 'Data on ' + timestamp

#extracting from the website's xml source and using urllib tool
            wu= 'https://www.wunderground.com/history/airport/KOAK/' + str(y) + '/' + str(m) + '/' + str(d) + '/DailyHistory.html?req_city=&req_state=&req_statename=&reqdb.zip=&reqdb.magic=&reqdb.wmo='
            weatherunderground = urllib2.urlopen(wu)

        #using soup to find the correct information from the data set
            soup = BeautifulSoup(weatherunderground)



            for row in soup.select("table tr.no-metars"):
                date.append(str(y) + '/' + str(m) + '/' + str(d))
                cells = [cell.text.strip().encode('ascii', 'ignore').decode('ascii') for cell in row.find_all('td')] #ASCI is decoded
                weather_data.append(cells)
# Out:
# Data on 201511
# C:\Program Files\Anaconda2\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file C:\Program Files\Anaconda2\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Data on 201512
# Data on 201513
# Data on 201514
# Data on 201515
# Data on 201516
# Data on 201517
# Data on 201518
# Data on 201519
# Data on 2015110
# Data on 2015111
# Data on 2015112
# Data on 2015113
# Data on 2015114
# Data on 2015115
# Data on 2015116
# Data on 2015117
# Data on 2015118
# Data on 2015119
# Data on 2015120
# Data on 2015121
# Data on 2015122
# Data on 2015123
# Data on 2015124
# Data on 2015125
# Data on 2015126
# Data on 2015127
# Data on 2015128
# Data on 2015129
# Data on 2015130
# Data on 2015131
# Data on 201521
# Data on 201522
# Data on 201523
# Data on 201524
# Data on 201525
# Data on 201526
# Data on 201527
# Data on 201528
# Data on 201529
# Data on 2015210
# Data on 2015211
# Data on 2015212
# Data on 2015213
# Data on 2015214
# Data on 2015215
# Data on 2015216
# Data on 2015217
# Data on 2015218
# Data on 2015219
# Data on 2015220
# Data on 2015221
# Data on 2015222
# Data on 2015223
# Data on 2015224
# Data on 2015225
# Data on 2015226
# Data on 2015227
# Data on 2015228
# Data on 2015229
# Data on 2015230
# Data on 2015231
# Data on 201531
# Data on 201532
# Data on 201533
# Data on 201534
# Data on 201535
# Data on 201536
# Data on 201537
# Data on 201538
# Data on 201539
# Data on 2015310
# Data on 2015311
# Data on 2015312
# Data on 2015313
# Data on 2015314
# Data on 2015315
# Data on 2015316
# Data on 2015317
# Data on 2015318
# Data on 2015319
# Data on 2015320
# Data on 2015321
# Data on 2015322
# Data on 2015323
# Data on 2015324
# Data on 2015325
# Data on 2015326
# Data on 2015327
# Data on 2015328
# Data on 2015329
# Data on 2015330
# Data on 2015331
# Data on 201541
# Data on 201542
# Data on 201543
# Data on 201544
# Data on 201545
# Data on 201546
# Data on 201547
# Data on 201548
# Data on 201549
# Data on 2015410
# Data on 2015411
# Data on 2015412
# Data on 2015413
# Data on 2015414
# Data on 2015415
# Data on 2015416
# Data on 2015417
# Data on 2015418
# Data on 2015419
# Data on 2015420
# Data on 2015421
# Data on 2015422
# Data on 2015423
# Data on 2015424
# Data on 2015425
# Data on 2015426
# Data on 2015427
# Data on 2015428
# Data on 2015429
# Data on 2015430
# Data on 201551
# Data on 201552
# Data on 201553
# Data on 201554
# Data on 201555
# Data on 201556
# Data on 201557
# Data on 201558
# Data on 201559
# Data on 2015510
# Data on 2015511
# Data on 2015512
# Data on 2015513
# Data on 2015514
# Data on 2015515
# Data on 2015516
# Data on 2015517
# Data on 2015518
# Data on 2015519
# Data on 2015520
# Data on 2015521
# Data on 2015522
# Data on 2015523
# Data on 2015524
# Data on 2015525
# Data on 2015526
# Data on 2015527
# Data on 2015528
# Data on 2015529
# Data on 2015530
# Data on 2015531
# Data on 201561
# Data on 201562
# Data on 201563
# Data on 201564
# Data on 201565
# Data on 201566
# Data on 201567
# Data on 201568
# Data on 201569
# Data on 2015610
# Data on 2015611
# Data on 2015612
# Data on 2015613
# Data on 2015614
# Data on 2015615
# Data on 2015616
# Data on 2015617
# Data on 2015618
# Data on 2015619
# Data on 2015620
# Data on 2015621
# Data on 2015622
# Data on 2015623
# Data on 2015624
# Data on 2015625
# Data on 2015626
# Data on 2015627
# Data on 2015628
# Data on 2015629
# Data on 2015630
# Data on 201571
# Data on 201572
# Data on 201573
# Data on 201574
# Data on 201575
# Data on 201576
# Data on 201577
# Data on 201578
# Data on 201579
# Data on 2015710
# Data on 2015711
# Data on 2015712
# Data on 2015713
# Data on 2015714
# Data on 2015715
# Data on 2015716
# Data on 2015717
# Data on 2015718
# Data on 2015719
# Data on 2015720
# Data on 2015721
# Data on 2015722
# Data on 2015723
# Data on 2015724
# Data on 2015725
# Data on 2015726
# Data on 2015727
# Data on 2015728
# Data on 2015729
# Data on 2015730
# Data on 2015731
# Data on 201581
# Data on 201582
# Data on 201583
# Data on 201584
# Data on 201585
# Data on 201586
# Data on 201587
# Data on 201588
# Data on 201589
# Data on 2015810
# Data on 2015811
# Data on 2015812
# Data on 2015813
# Data on 2015814
# Data on 2015815
# Data on 2015816
# Data on 2015817
# Data on 2015818
# Data on 2015819
# Data on 2015820
# Data on 2015821
# Data on 2015822
# Data on 2015823
# Data on 2015824
# Data on 2015825
# Data on 2015826
# Data on 2015827
# Data on 2015828
# Data on 2015829
# Data on 2015830
# Data on 2015831
# Data on 201591
# Data on 201592
# Data on 201593
# Data on 201594
# Data on 201595
# Data on 201596
# Data on 201597
# Data on 201598
# Data on 201599
# Data on 2015910
# Data on 2015911
# Data on 2015912
# Data on 2015913
# Data on 2015914
# Data on 2015915
# Data on 2015916
# Data on 2015917
# Data on 2015918
# Data on 2015919
# Data on 2015920
# Data on 2015921
# Data on 2015922
# Data on 2015923
# Data on 2015924
# Data on 2015925
# Data on 2015926
# Data on 2015927
# Data on 2015928
# Data on 2015929
# Data on 2015930
# Data on 2015101
# Data on 2015102
# Data on 2015103
# Data on 2015104
# Data on 2015105
# Data on 2015106
# Data on 2015107
# Data on 2015108
# Data on 2015109
# Data on 20151010
# Data on 20151011
# Data on 20151012
# Data on 20151013
# Data on 20151014
# Data on 20151015
# Data on 20151016
# Data on 20151017
# Data on 20151018
# Data on 20151019
# Data on 20151020
# Data on 20151021
# Data on 20151022
# Data on 20151023
# Data on 20151024
# Data on 20151025
# Data on 20151026
# Data on 20151027
# Data on 20151028
# Data on 20151029
# Data on 20151030
# Data on 20151031
# Data on 2015111
# Data on 2015112
# Data on 2015113
# Data on 2015114
# Data on 2015115
# Data on 2015116
# Data on 2015117
# Data on 2015118
# Data on 2015119
# Data on 20151110
# Data on 20151111
# Data on 20151112
# Data on 20151113
# Data on 20151114
# Data on 20151115
# Data on 20151116
# Data on 20151117
# Data on 20151118
# Data on 20151119
# Data on 20151120
# Data on 20151121
# Data on 20151122
# Data on 20151123
# Data on 20151124
# Data on 20151125
# Data on 20151126
# Data on 20151127
# Data on 20151128
# Data on 20151129
# Data on 20151130
# Data on 2015121
# Data on 2015122
# Data on 2015123
# Data on 2015124
# Data on 2015125
# Data on 2015126
# Data on 2015127
# Data on 2015128
# Data on 2015129
# Data on 20151210
# Data on 20151211
# Data on 20151212
# Data on 20151213
# Data on 20151214
# Data on 20151215
# Data on 20151216
# Data on 20151217
# Data on 20151218
# Data on 20151219
# Data on 20151220
# Data on 20151221
# Data on 20151222
# Data on 20151223
# Data on 20151224
# Data on 20151225
# Data on 20151226
# Data on 20151227
# Data on 20151228
# Data on 20151229
# Data on 20151230
# Data on 20151231

# %%
#We create a data frame to capture the data
weather_datadf = pd.DataFrame(weather_data)
datedf = pd.DataFrame(date)
result = pd.concat([datedf, weather_datadf], axis=1)
result
# Out:
#               0         0      1      2      3    4        5       6   \
# 0       2015/1/1  12:53 AM  45.0F  42.6F  14.0F  29%  30.07in  10.0mi
# 1       2015/1/1   1:53 AM  45.0F  41.8F  15.1F  30%  30.09in  10.0mi
# 2       2015/1/1   2:53 AM  44.1F  36.5F  18.0F  35%  30.09in  10.0mi
# 3       2015/1/1   3:53 AM  45.0F  39.7F  17.1F  33%  30.08in  10.0mi
# 4       2015/1/1   4:53 AM  43.0F  38.8F  18.0F  37%  30.09in  10.0mi
# 5       2015/1/1   5:53 AM  41.0F  38.0F  19.9F  43%  30.10in  10.0mi
# 6       2015/1/1   6:53 AM  42.1F  37.7F  19.9F  41%  30.11in  10.0mi
# 7       2015/1/1   7:53 AM  45.0F  38.5F  18.0F  34%  30.12in  10.0mi
# 8       2015/1/1   8:53 AM  48.9F      -  19.0F  31%  30.15in  10.0mi
# 9       2015/1/1   9:53 AM  51.1F      -  19.9F  29%  30.17in  10.0mi
# 10      2015/1/1  10:53 AM  53.1F      -  17.1F  24%  30.16in  10.0mi
# 11      2015/1/1  11:53 AM  54.0F      -  21.0F  28%  30.14in  10.0mi
# 12      2015/1/1  12:53 PM  55.0F      -  19.0F  24%  30.12in  10.0mi
# 13      2015/1/1   1:53 PM  55.0F      -  19.0F  24%  30.10in  10.0mi
# 14      2015/1/1   2:53 PM  55.0F      -  16.0F  22%  30.11in  10.0mi
# 15      2015/1/1   3:53 PM  54.0F      -  17.1F  23%  30.13in  10.0mi
# 16      2015/1/1   4:53 PM  48.0F      -  19.9F  33%  30.14in  10.0mi
# 17      2015/1/1   5:53 PM  46.9F      -  19.0F  33%  30.14in  10.0mi
# 18      2015/1/1   6:53 PM  48.0F      -  18.0F  30%  30.15in  10.0mi
# 19      2015/1/1   7:53 PM  46.0F      -  18.0F  33%  30.15in  10.0mi
# 20      2015/1/1   8:53 PM  43.0F      -  21.0F  42%  30.16in  10.0mi
# 21      2015/1/1   9:44 PM  41.0F      -  24.8F  53%  30.16in  10.0mi
# 22      2015/1/1   9:53 PM  41.0F  39.0F  23.0F  49%  30.17in  10.0mi
# 9770  2015/12/31  11:53 PM  39.9F      -  28.0F  63%  30.15in  10.0mi
#
#             7        8        9    10 11                12
# 0          NNE   4.6mph        -  N/A                Clear
# 1        North   5.8mph        -  N/A                Clear
# 2           NE  17.3mph  23.0mph  N/A                Clear
# 3          ENE  10.4mph  20.7mph  N/A                Clear
# 4          NNE   6.9mph        -  N/A                Clear
# 5           NE   4.6mph        -  N/A                Clear
# 6           NE   6.9mph        -  N/A                Clear
# 7          ENE  13.8mph  23.0mph  N/A                Clear
# 8          ENE   9.2mph        -  N/A                Clear
# 9          ENE  13.8mph        -  N/A                Clear
# 10         NNE  11.5mph  20.7mph  N/A                Clear
# 11          NE  13.8mph        -  N/A                Clear
# 12          NE  11.5mph        -  N/A                Clear
# 13         NNE  13.8mph  21.9mph  N/A                Clear
# 14         NNE  16.1mph  21.9mph  N/A                Clear
# 15         NNE   6.9mph        -  N/A                Clear
# 16         NNE   8.1mph        -  N/A                Clear
# 17       North   8.1mph        -  N/A                Clear
# 18        Calm     Calm        -  N/A                Clear
# 19        Calm     Calm        -  N/A                Clear
# 20        Calm     Calm        -  N/A                Clear
# 21        Calm     Calm        -  N/A        Mostly Cloudy
# 22         ENE   3.5mph        -  N/A        Mostly Cloudy
# 23         ENE   3.5mph        -  N/A     Scattered Clouds
# 24        Calm     Calm        -  N/A        Partly Cloudy
# 25        Calm     Calm        -  N/A        Mostly Cloudy
# 26         ENE   3.5mph        -  N/A        Mostly Cloudy
# 27         NNE   3.5mph        -  N/A        Mostly Cloudy
# 28         ENE   4.6mph        -  N/A     Scattered Clouds
# 29         ESE   3.5mph        -  N/A        Partly Cloudy
# ...        ...      ...      ...  ... ..               ...
# 9741        NE   5.8mph        -  N/A             Overcast
# 9742       ENE   9.2mph        -  N/A             Overcast
# 9743        NE   8.1mph        -  N/A             Overcast
# 9744       ENE   9.2mph        -  N/A        Mostly Cloudy
# 9745        NE   4.6mph        -  N/A        Mostly Cloudy
# 9746      East   6.9mph        -  N/A             Overcast
# 9747      Calm     Calm        -  N/A        Partly Cloudy
# 9748      Calm     Calm        -  N/A                Clear
# 9749        NE   3.5mph        -  N/A                Clear
# 9750       NNE   3.5mph        -  N/A                Clear
# 9751  Variable   3.5mph        -  N/A                Clear
# 9752       NNE   3.5mph        -  N/A                Clear
# 9753       NNE   9.2mph        -  N/A                Clear
# 9754        SE   3.5mph        -  N/A                Clear
# 9755       NNE  13.8mph        -  N/A                Clear
# 9756       NNE   5.8mph        -  N/A                Clear
# 9757       ENE   9.2mph        -  N/A                Clear
# 9758        NE   8.1mph        -  N/A        Partly Cloudy
# 9759       NNE   8.1mph        -  N/A        Partly Cloudy
# 9760       NNE  12.7mph        -  N/A        Partly Cloudy
# 9761       NNE  15.0mph        -  N/A        Partly Cloudy
# 9762       NNE  11.5mph        -  N/A                Clear
# 9763     North   6.9mph        -  N/A                Clear
# 9764      Calm     Calm        -  N/A                Clear
# 9765      East   3.5mph        -  N/A                Clear
# 9766      Calm     Calm        -  N/A                Clear
# 9767        SE   6.9mph        -  N/A                Clear
# 9768       SSE   3.5mph        -  N/A                Clear
# 9769  Variable   3.5mph        -  N/A                Clear
# 9770      Calm     Calm        -  N/A                Clear
#
# [9771 rows x 14 columns]

# %%
result.to_csv('weatherdata2015.csv')   #saves it as a CSV
